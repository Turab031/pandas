# %%
import pandas as pd

# %%
info={
    "name":["rahul","harsh","jatin"],
    "cgpa":[9.5,8.5,9.5]
}

df = pd.DataFrame(info)
print(df)
# Out:
#     name  cgpa
# 0  rahul   9.5
# 1  harsh   8.5
# 2  jatin   9.5

# %%
s = pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
age = pd.Series([23,24,45,29],index=["adam","bob","charlie","eve"])
print(age)
# Out:
# adam       23
# bob        24
# charlie    45
# eve        29
# dtype: int64

# %%
s1 = pd.Series([1,2,3,4,5])
s2= pd.Series([6,7,8,9,10])
print(s1+s2)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64
