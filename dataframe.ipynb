# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
info = {
    "name":["adam","eve","bob"],
    "age":[23,24,25],
    "gpa":[9.5,8.6,7.2]

}

df = pd.DataFrame(info)
print(df)
# Out:
#    name  age  gpa
# 0  adam   23  9.5
# 1   eve   24  8.6
# 2   bob   25  7.2

# %%
df = pd.DataFrame(
    [["adam", 24], ["bob", 23], ["eve", 23]],
    columns=["name", "age"]
)

print(df)
# Out:
#    name  age
# 0  adam   24
# 1   bob   23
# 2   eve   23

# %%
import numpy as np

# %%
np_Arr = np.array([[1,2,3],[4,5,6]])

df = pd.DataFrame(np_Arr,columns=["a","b","c"])
print(df)
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
